# %%
import tensorflow as tf
import libspn as spn

# %%
v1 = spn.IVs(num_vars=1, num_vals=2, name="X1")
v2 = spn.IVs(num_vars=1, num_vals=2, name="X2")
s11 = spn.Sum(v1, name="Sum1.1")
s12 = spn.Sum(v1, name="Sum1.2")
s21 = spn.Sum(v2, name="Sum2.1")
s22 = spn.Sum(v2, name="Sum2.2")
p1 = spn.Product(s11, s21, name="Prod1")
p2 = spn.Product(s11, s22, name="Prod2")
p3 = spn.Product(s12, s22, name="Prod3")
s = spn.Sum(p1, p2, p3, name="Sum")
spn.generate_weights(s)

# %%
spn.display_spn_graph(s)

# %%
value=s.get_value()
spn.display_tf_graph()
# Out:
#         <iframe seamless style="width:1300px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.535080289438897&quot;).pbtxt = 'node {\n  name: &quot;X1/Placeholder&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;X2/Placeholder&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Sum2.2_Weights/broadcast_value/Const&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 1.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Sum2.2_Weights/broadcast_value/Fill/dims&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 1\n          }\n        }\n        int_val: 2\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Sum2.2_Weights/broadcast_value/Fill&quot;\n  op: &quot;Fill&quot;\n  input: &quot;Sum2.2_Weights/broadcast_value/Fill/dims&quot;\n  input: &quot;Sum2.2_Weights/broadcast_value/Const&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;Sum2.2_Weights/normalize_tensor/Const&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 1\n          }\n        }\n        int_val: 0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Sum2.2_Weights/normalize_tensor/Sum&quot;\n  op: &quot;Sum&quot;\n  input: &quot;Sum2.2_Weights/broadcast_value/Fill&quot;\n  input: &quot;Sum2.2_Weights/normalize_tensor/Const&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;keep_dims&quot;\n    value {\n      b: false\n    }\n  }\n}\nnode {\n  name: &quot;Sum2.2_Weights/normalize_tensor/truediv&quot;\n  op: &quot;Div&quot;\n  input: &quot;Sum2.2_Weights/broadcast_value/Fill&quot;\n  input: &quot;Sum2.2_Weights/normalize_tensor/Sum&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;Sum2.2_Weights/Variable&quot;\n  op: &quot;Variable&quot;\n  attr {\n    key: &quot;container&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: 2\n        }\n      }\n    }\n  }\n  attr {\n    key: &quot;shared_name&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n}\nnode {\n  name: &quot;Sum2.2_Weights/Variable/Assign&quot;\n  op: &quot;Assign&quot;\n  input: &quot;Sum2.2_Weights/Variable&quot;\n  input: &quot;Sum2.2_Weights/normalize_tensor/truediv&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@Sum2.2_Weights/Variable&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;use_locking&quot;\n    value {\n      b: true\n    }\n  }\n  attr {\n    key: &quot;validate_shape&quot;\n    value {\n      b: true\n    }\n  }\n}\nnode {\n  name: &quot;Sum2.2_Weights/Variable/read&quot;\n  op: &quot;Identity&quot;\n  input: &quot;Sum2.2_Weights/Variable&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &qu ...

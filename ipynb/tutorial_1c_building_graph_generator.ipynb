# %% [markdown]
# # Tutorial 1c: Building the SPN Graph Using A Generator

# %%
import libspn as spn

# %% [markdown]
# ### Build

# %%
iv_x = spn.IVs(num_vars=2, num_vals=2, name="iv_x")
gen=spn.DenseSPNGenerator(num_decomps=1, num_subsets=2, num_mixtures=2)
root=gen.generate(iv_x, root_name="root")
iv_y = root.generate_ivs(name="iv_y") # Can be added manually
spn.generate_weights(root, init_value=spn.ValueType.RANDOM_UNIFORM(0, 1)) # Can be added manually

# %% [markdown]
# ### Inspect

# %%
print(root.get_num_nodes())
print(root.get_scope())
print(root.is_valid())
# Out:
# 16
# [Scope({iv_x:1, iv_x:0, iv_y:0})]
# True

# %% [markdown]
# ### Visualize the SPN Graph

# %%
spn.display_spn_graph(root)
# Out:
# <svg id="Sda49ba20136145838137123d18b7b703" width="950" height="800"></svg>
# <script>
#  require.config({
#    paths: {
#      d3: 'https://d3js.org/d3.v4.min'
#    }
#  });
#  require(['d3'], function(d3){
#
#    var graph = {"links": [{"value": 2, "target": "Sums1.2/Sum2", "source": "Weights/Sums1.2/Sum2_Weights_1"}, {"value": 1, "target": "Sums1.2/Sum2", "source": "iv_x_2"}, {"value": 1, "target": "Sums1.2/Sum2", "source": "iv_x_3"}, {"value": 2, "target": "Sums1.1/Sum2", "source": "Weights/Sums1.1/Sum2_Weights_4"}, {"value": 1, "target": "Sums1.1/Sum2", "source": "iv_x_5"}, {"value": 1, "target": "Sums1.1/Sum2", "source": "iv_x_6"}, {"value": 1, "target": "Products1/Product4", "source": "Sums1.1/Sum2"}, {"value": 1, "target": "Products1/Product4", "source": "Sums1.2/Sum2"}, {"value": 2, "target": "Sums1.1/Sum1", "source": "Weights/Sums1.1/Sum1_Weights_7"}, {"value": 1, "target": "Sums1.1/Sum1", "source": "iv_x_8"}, {"value": 1, "target": "Sums1.1/Sum1", "source": "iv_x_9"}, {"value": 1, "target": "Products1/Product3", "source": "Sums1.1/Sum1"}, {"value": 1, "target": "Products1/Product3", "source": "Sums1.2/Sum2"}, {"value": 2, "target": "Sums1.2/Sum1", "source": "Weights/Sums1.2/Sum1_Weights_10"}, {"value": 1, "target": "Sums1.2/Sum1", "source": "iv_x_11"}, {"value": 1, "target": "Sums1.2/Sum1", "source": "iv_x_12"}, {"value": 1, "target": "Products1/Product2", "source": "Sums1.1/Sum2"}, {"value": 1, "target": "Products1/Product2", "source": "Sums1.2/Sum1"}, {"value": 1, "target": "Products1/Product1", "source": "Sums1.1/Sum1"}, {"value": 1, "target": "Products1/Product1", "source": "Sums1.2/Sum1"}, {"value": 4, "target": "root", "source": "Weights/root_Weights_13"}, {"value": 4, "target": "root", "source": "iv_y_14"}, {"value": 1, "target": "root", "source": "Products1/Product1"}, {"value": 1, "target": "root", "source": "Products1/Product2"}, {"value": 1, "target": "root", "source": "Products1/Product3"}, {"value": 1, "target": "root", "source": "Products1/Product4"}], "nodes": [{"tooltip": "Sums1.2/Sum2", "id": "Sums1.2/Sum2", "name": "Sums1.2/Sum2", "type": 2}, {"tooltip": "Weights/Sums1.2/Sum2_Weights", "id": "Weights/Sums1.2/Sum2_Weights_1", "name": "Weights/Sums1.2/Sum2_Weights", "type": 1}, {"tooltip": "iv_x", "id": "iv_x_2", "name": "iv_x[2]", "type": 0}, {"tooltip": "iv_x", "id": "iv_x_3", "name": "iv_x[3]", "type": 0}, {"tooltip": "Sums1.1/Sum2", "id": "Sums1.1/Sum2", "name": "Sums1.1/Sum2", "type": 2}, {"tooltip": "Weights/Sums1.1/Sum2_Weights", "id": "Weights/Sums1.1/Sum2_Weights_4", "name": "Weights/Sums1.1/Sum2_Weights", "type": 1}, {"tooltip": "iv_x", "id": "iv_x_5", "name": "iv_x[0]", "type": 0}, {"tooltip": "iv_x", "id": "iv_x_6", "name": "iv_x[1]", "type": 0}, {"tooltip": "Products1/Product4", "id": "Products1/Product4", "name": "Products1/Product4", "type": 3}, {"tooltip": "Sums1.1/Sum1", "id": "Sums1.1/Sum1", "name": "Sums1.1/Sum1", "type": 2}, {"tooltip": "Weights/Sums1.1/Sum1_Weights", "id": "Weights/Sums1.1/Sum1_Weights_7", "name": "Weights/Sums1.1/Sum1_Weights", "type": 1}, {"tooltip": "iv_x", "id": "iv_x_8", "name": "iv_x[0]", "type": 0}, {"tooltip": "iv_x", "id": "iv_x_9", "name": "iv_x[1]", "type": 0}, {"tooltip": "Products1/Product3", "id": "Products1/Product3", "name": "Products1/Product3", "type": 3}, {"tooltip": "Sums1.2/Sum1", "id": "Sums1.2/Sum1", "name": "Sums1.2/Sum1", "type": 2}, {"tooltip": "Weights/Sums1.2/Sum1_Weights", "id": "Weights/Sums1.2/Sum1_Weights_10", "name": "Weights/Sums1.2/Sum1_Weights", "type": 1}, {"tooltip": "iv_x", "id": "iv_x_11", "name": "iv_x[2]", "type": 0}, {"tooltip": "iv_x", "id": "iv_x_12", "name": "iv_x[3]", "type": 0}, {"tooltip": "Products1/Product2", "id": "Products1/Product2", "name": "Products1/Product2", "type": 3}, {"tooltip": "Products1/Product1", "id": "Products1/Product1", "name": "Products1/Product1", "type": 3}, {"tooltip": "root", "id": "root", "name": "root", "type": 2}, {"tooltip": "Weights/root_Weights", "id": "Weights/root_Weights_13", "name": "Weights/root_Weights", "type": 1}, {"tooltip": "iv_y", "id": "iv_y_14", "name": "iv_y", "type": 0}]};
#
#    var color = d3.scaleOrdinal(d3.schemeCategory10);
#
#    var zoom = d3.zoom()
#                 .scaleExtent([0.1, 10])
#                 .on("zoom", zoomed);
#
#    var svg = d3.select("#Sda49ba20136145838137123d18b7b703").
#                 call(zoom);
#
#    var width = svg.attr("width");
#    var height = svg.attr("height");
#
#    var simulation = d3.forceSimulation(graph.nodes)
#                       .on("tick", ticked)
#                       .force("link", d3.forceLink(graph.links)
#                                        .distance(80)
#                                        .id(function(d) { return d.id; }))
#                       .force("charge", d3.forceManyBody().
#                                           strength(-1000))
#                       .force("center", d3.forceCenter(width / 2, height / 2));
#
#    /* Contents */
#    var container = svg.append("g").
#                        attr("class", "container");
#
#    var link = container.append("g")
#                        .selectAll("link")
#                        .data(graph.links)
#                        .enter().append("line")
#                        .attr("stroke", "#444")
#                        .attr("stroke-opacity", "0.6")
#                        .attr("stroke-width",
#                              function(d) {
#                                return d.value;
#                                /*return Math.sqrt(d.value);*/
#                              });
#
#    var link_value = container.append("g")
#                              .selectAll("linkvalue")
#                              .data(graph.links)
#                              .enter().append("text")
#                              .attr("alignment-baseline", "middle")
#                              .style("text-anchor", "middle")
#                              .text(function(d) { return d.value; });
#
#    var node = container.append("g")
#                        .selectAll("node")
#                        .data(graph.nodes)
#                        .enter().append("g")
#                        .call(d3.drag()
#                                .on("start", dragstarted)
#                                .on("drag", dragged)
#                                .on("end", dragended));
#
#    /* Node appearance */
#    node.append("rect")
#        .attr("height", 0)
#        .attr("width", 0)
#        .attr("fill", function(d) { return color(d.type); })
#        .attr("stroke", "#000")
#        .attr("stroke-width", "1px");
#
#    node.append("text")
#        .attr("alignment-baseline", "middle")
#        .style("text-anchor", "middle")
#        .text(function(d) { return d.name; });
#
#    /* Adjust rect width to text */
#    var margin=10;
#    node.selectAll('rect')
#        .attr("x", function(d) {return d3.select(this).attr("x") - (this.parentNode.getBBox().width + margin)/2.0;})
#        .attr("y", function(d) {return d3.select(this).attr("y") - (this.parentNode.getBBox().height + margin)/2.0;})
#        .attr("width", function(d) {return this.parentNode.getBBox().width + margin;})
#        .attr("height", function(d) {return this.parentNode.getBBox().height + margin;});
#
#    /* Tooltips */
#    node.append("title")
#        .text(function(d) { return d.tooltip; });
#
#    /* Functions */
#    function zoomed() {
#      container.attr("transform", d3.event.transform);
#    }
#
#    function ticked() {
#      link
#        .attr("x1", function(d) { return d.source.x; })
#        .attr("y1", function(d) { return d.source.y; })
#        .attr("x2", function(d) { return d.target.x; })
#        .attr("y2", function(d) { return d.target.y; });
#
#      link_value
#        .attr("x", function(d) { return (d.source.x+d.target.x)/2; })
#        .attr("y", function(d) { return (d.source.y+d.target.y)/2; })
#
#      node.attr("transform",
#                function(d) { return "translate(" + d.x + "," + d.y + ")"; });
#    }
#
#    function dragstarted(d) {
#      if (!d3.event.active) simulation.alphaTarget(0.3).restart();
#      d.fx = d.x;
#      d.fy = d.y;
#    }
#
#    function dragged(d

# %%
import libspn as spn
import tensorflow as tf
import numpy as np

# %% [markdown]
# # Params

# %% [markdown]
# ### Data

# %%
# Number of values of each variable
num_vals = 10 # 20  

# Number of samples in dataset
num_samples = 1000

# Batch size
batch_size = 1000

# Num epochs
num_epochs = 20

batches_per_epoch = num_samples/batch_size
print(batches_per_epoch)
if int(batches_per_epoch) != batches_per_epoch:
    raise Exception
batches_per_epoch=int(batches_per_epoch)
# Out:
# 1.0

# %% [markdown]
# ### Structure

# %%
# Type of input distributions for dense generator
input_dist = spn.DenseSPNGenerator.InputDist.RAW  

# Number of input mixtures for dense generator
num_input_mixtures = 10 # 10?

# %% [markdown]
# ### Learning

# %%
# Additive smoothing during learning
additive_smoothing=100
min_additive_smoothing=1
smoothing_decay=0.2

# Weight initialization
#weight_init_value = 1
weight_init_value = spn.ValueType.RANDOM_UNIFORM(10, 11)

# Type of inference during upward pass of learning
value_inference_type = spn.InferenceType.MARGINAL

# %% [markdown]
# # Generate Training Set

# %%
components = [spn.GaussianMixtureDataset.Component(0.1, [1,1], [[1,0],[0,1]]),
              spn.GaussianMixtureDataset.Component(0.2, [1,4], [[1,0.4],[0.8,1]]),
              spn.GaussianMixtureDataset.Component(0.1, [1,8], [[1,0],[0,1]]),
              spn.GaussianMixtureDataset.Component(0.1, [3,4], [[0.5,0],[0,0.7]]),
              spn.GaussianMixtureDataset.Component(0.1, [3,8], [[1,0],[0,1]]),
              spn.GaussianMixtureDataset.Component(0.1, [5,4], [[1,0],[0,1]]),
              spn.GaussianMixtureDataset.Component(0.3, [5,1], [[1,0.5],[0.5,1]])]

train_set = spn.GaussianMixtureDataset(components=components,
                                     num_samples=num_samples,
                                     num_epochs=num_epochs,
                                     batch_size=batch_size,
                                     shuffle=True,
                                     num_threads=1,
                                     allow_smaller_final_batch=False,
                                     num_vals=num_vals)

# %%
train_samples, labels, true_likelihoods = train_set.get_data()

# %% [markdown]
# # Generate SPN Structure

# %%
ivs = spn.IVs(num_vars=2, num_vals=num_vals)
dense_gen = spn.DenseSPNGenerator(num_decomps=1, num_subsets=2, num_mixtures=1, 
                                  input_dist=input_dist, 
                                  num_input_mixtures=num_input_mixtures)
root = dense_gen.generate(ivs)
spn.generate_weights(root, init_value=weight_init_value)

# %%
# spn.display_spn_graph(root)

# %% [markdown]
# # Add Learning Ops

# %%
ivs.attach_feed(train_samples)
additive_smoothing_var = tf.Variable(additive_smoothing, dtype=spn.conf.dtype)
learning = spn.EMLearning(root, log=False, value_inference_type = value_inference_type,
                          additive_smoothing=additive_smoothing_var)
init_weights = spn.initialize_weights(root)
reset_accumulators = learning.reset_accumulators()
accumulate_updates = learning.accumulate_updates()
update_spn = learning.update_spn()
train_likelihood=learning.value.values[root]
avg_train_likelihood = tf.reduce_mean(train_likelihood)

# %%
# spn.display_tf_graph()

# %% [markdown]
# # Generate Test Set

# %%
test_set = spn.IntGridDataset(num_dims=2,
                              num_vals=num_vals,
                              num_epochs=1,
                              batch_size=1000,
                              shuffle=False,
                              num_threads=1,
                              allow_smaller_final_batch=True)

# %%
test_samples = test_set.get_data()

# %% [markdown]
# # Add Testing Ops

# %%
ivs.attach_feed(test_samples)

# %%
test_likelihoods = root.get_value(inference_type=spn.InferenceType.MARGINAL)

# %%
# spn.display_tf_graph()

# %% [markdown]
# # Run

# %%
with spn.session() as (sess, run):
    sess.run(additive_smoothing_var.initializer)
    sess.run(init_weights)
    sess.run(reset_accumulators)
    
    # Run training
    epoch=1
    epoch_done=0
    epoch_batch=0
    try:
        while run():
            # Calculcate epoch and batch
            epoch_batch+=1
            if epoch_batch>batches_per_epoch:
                epoch_batch=1
                epoch+=1
            print("Epoch: %s Batch: %s" % (epoch, epoch_batch))
            # Every epoch, including first
            if epoch_done != epoch:
                epoch_done = epoch
                # Save SPN
                saver=spn.JSONSaver("/home/czikus/model_%s.spn" % (epoch-1), pretty=True)
                saver.save(root)
                # Reset/init accumulators
                # sess.run(reset_accumulators)
                # Adjust additive smoothing
                ads=max(np.exp(-(epoch-1)*smoothing_decay)*additive_smoothing, min_additive_smoothing)
                sess.run(additive_smoothing_var.assign(ads))
                print("Smoothing: ", sess.run(additive_smoothing_var))
                print("Accumulators RESET!")
            # Run accumulate_updates
            train_samples_arr, labels_arr, train_likelihoods_arr, avg_train_likelihood_val, \
            true_likelihoods_arr, _, \
            root_accum_arr, root_values_weighted, root_values_values, root_weights = \
                sess.run([train_samples, labels, 
                          train_likelihood, avg_train_likelihood,
                          true_likelihoods,
                          accumulate_updates,
                          # Testing
                          learning.root_accum(), spn.Sum.values_weighted, 
                          spn.Sum.values_values, root.weights.node.variable
                         ])
            # Print avg likelihood of this batch data on previous batch weights
            print("Avg likelihood (this batch data on previous weights): %s" % (avg_train_likelihood_val))

            # ----------------------------
            # TEST STUFF
            # - accumulator for root
            # print("This batch data:", train_samples_arr)
            # print("This batch accum:", root_accum_arr)
            # print("Preious batch weights:", root_weights)
            #print("Values:", root_values_values)
            #print("Values weighted:", root_values_weighted)
            
            # ----------------------------

            # Update weights
            sess.run(update_spn)
            
    except tf.errors.OutOfRangeError:
        print("TRAINING DONE!")
    
    # Run testing
    try:
        while run():
            test_samples_arr, test_likelihoods_arr = sess.run([test_samples, test_likelihoods])
#            spn.plot_2d(test_samples_arr[:, 0], test_samples_arr[:, 1], probs=likelihoods_arr.ravel(), jitter=False)
    except tf.errors.OutOfRangeError:
        print("TESTING DONE!")
# Out:
# Epoch: 1 Batch: 1
# Smoothing:  100.0
# Accumulators RESET!
# Avg likelihood (this batch data on previous weights): 0.010022
# Epoch: 2 Batch: 1
# Smoothing:  81.8731
# Accumulators RESET!
# Avg likelihood (this batch data on previous weights): 0.0119576
# Epoch: 3 Batch: 1
# Smoothing:  67.032
# Accumulators RESET!
# Avg likelihood (this batch data on previous weights): 0.0142276
# Epoch: 4 Batch: 1
# Smoothing:  54.8812
# Accumulators RESET!
# Avg likelihood (this batch data on previous weights): 0.0166578
# Epoch: 5 Batch: 1
# Smoothing:  44.9329
# Accumulators RESET!
# Avg likelihood (this batch data on previous weights): 0.0190783
# Epoch: 6 Batch: 1
# Smoothing:  36.7879
# Accumulators RESET!
# Avg likelihood (this batch data on previous weights): 0.0213417
# Epoch: 7 Batch: 1
# Smoothing:  30.1194
# Accumulators RESET!
# Avg likelihood (this batch data on previous weights): 0.0233492
# Epoch: 8 Batch: 1
# Smoothing:  24.6597
# Accumulators RESET!
# Avg likelihood (this batch data on previous weights): 0.0250558
# Epoch: 9 Batch: 1
# Smoothing:  20.1897
# Accumulators RESET!
# Avg likelihood (this batch data on previous weights): 0.0264602
# Epoch: 10 Batch: 1
# Smoothing:  16.5299
# Accumulators RESET!
# Avg likelihood (this batch data on previous weights): 0.0275884
# Epoch: 11 Batch: 1
# Smoothing:  13.5335
# Accumulators RESET!
# Avg likelihood (this batch data on previous weights): 0.0284794
# Epoch: 12 Batch: 1
# Smoothing:  11.0803
# Accumulators RESET!
# Avg likelihood (this batch data on previous weights): 0.0291749
# Epoch: 13 Batch: 1
# Smoothing:  9.0718
# Accumulators RESET!
# Avg likelihood (this batch data on previous weights): 0.0297137
# Epoch: 14 Batch: 1
# Smoothing:  7.42736
# Accumulators RESET!
# Avg likelihood (this batch data on previous weights): 0.0301293
# Epoch: 15 Batch: 1
# Smoothing:  6.08101
# Accumulators RESET!
# Avg likelihood (this batch data on previous weights): 0.0304491
# Epoch: 16 Batch: 1
# Smoothing:  4.97871
# Accumulators RESET!
# Avg likelihood (this batch data on previous weights): 0.030695
# Epoch: 17 Batch: 1
# Smoothing:  4.07622
# Accumulators RESET!
# Avg likelihood (this batch data on previous weights): 0.0308841
# Epoch: 18 Batch: 1
# Smoothing:  3.33733
# Accumulators RESET!
# Avg likelihood (this batch data on previous weights): 0.0310298
# Epoch: 19 Batch: 1
# Smoothing:  2.73237
# Accumulators RESET!
# Avg likelihood (this batch data on previous weights): 0.031142
# Epoch: 20 Batch: 1
# Smoothing:  2.23708
# Accumulators RESET!
# Avg likelihood (this batch data on previous weights): 0.0312287
# Epoch: 21 Batch: 1
# Smoothing:  1.83156
# Accumulators RESET!
# TRAINING DONE!
# TESTING DONE!

# %%
spn.plot_2d(train_samples_arr[:, 0], train_samples_arr[:, 1], labels=labels_arr[:, 0], probs=true_likelihoods_arr)

# %%
spn.plot_2d(train_samples_arr[:, 0], train_samples_arr[:, 1], labels=labels_arr[:, 0],
            probs=(train_likelihoods_arr.ravel()), jitter=True)

# %%
spn.plot_2d(test_samples_arr[:, 0], test_samples_arr[:, 1], 
            probs=(test_likelihoods_arr.ravel()), jitter=False)

# %%
# for s, l in zip(test_samples_arr, likelihoods_arr):
#    print(s.tolist(), l.tolist())

# %% [markdown]
# # Scratch

# %%
local_vars=tf.local_variables()

# %%
local_vars[0].name
# Out:
# 'Dataset/input_producer/input_producer/fraction_of_32_full/limit_epochs/epochs:0'

# %%
local_vars[1].name
# Out:
# 'Dataset_1/input_producer/input_producer/fraction_of_32_full/limit_epochs/epochs:0'

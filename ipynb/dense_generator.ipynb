# %%
import libspn as spn

# %%
gen=spn.DenseSPNGenerator(num_decomps=1, num_subsets=3, num_mixtures=4, num_input_mixtures=2, balanced=True,
                         input_dist=spn.DenseSPNGenerator.InputDist.RAW)

# %%
ivs=spn.IVs(num_vars=21*7, num_vals=3)

# %%
root=gen.generate(ivs)

# %%
root.get_num_nodes()
# Out:
# 3336

# %%
root.is_valid()
# Out:
# True

# %%
spn.display_spn_graph(root)
# Out:
# <svg id="S2e34c1b5bc014ddf866808f8f774b148" width="950" height="800"></svg>
# <script>
#  require.config({
#    paths: {
#      d3: 'https://d3js.org/d3.v4.min'
#    }
#  });
#  require(['d3'], function(d3){
#
#    var graph = {"nodes": [{"id": "Products21_1/Product4", "type": 1, "tooltip": "Products21_1/Product4", "name": "Products21_1/Product4"}, {"id": "IVs_1_1", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[27]"}, {"id": "IVs_1_2", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[31]"}, {"id": "Products21_1/Product3", "type": 1, "tooltip": "Products21_1/Product3", "name": "Products21_1/Product3"}, {"id": "IVs_1_3", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[26]"}, {"id": "IVs_1_4", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[31]"}, {"id": "Products21_1/Product2", "type": 1, "tooltip": "Products21_1/Product2", "name": "Products21_1/Product2"}, {"id": "IVs_1_5", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[27]"}, {"id": "IVs_1_6", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[30]"}, {"id": "Products21_1/Product1", "type": 1, "tooltip": "Products21_1/Product1", "name": "Products21_1/Product1"}, {"id": "IVs_1_7", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[26]"}, {"id": "IVs_1_8", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[30]"}, {"id": "Sums13.1_1/Sum2", "type": 2, "tooltip": "Sums13.1_1/Sum2", "name": "Sums13.1_1/Sum2"}, {"id": "Products13_1/Product8", "type": 1, "tooltip": "Products13_1/Product8", "name": "Products13_1/Product8"}, {"id": "IVs_1_9", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[63]"}, {"id": "IVs_1_10", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[11]"}, {"id": "Sums13.1_1/Sum1", "type": 2, "tooltip": "Sums13.1_1/Sum1", "name": "Sums13.1_1/Sum1"}, {"id": "Products13_1/Product7", "type": 1, "tooltip": "Products13_1/Product7", "name": "Products13_1/Product7"}, {"id": "IVs_1_11", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[63]"}, {"id": "IVs_1_12", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[11]"}, {"id": "Products13_1/Product6", "type": 1, "tooltip": "Products13_1/Product6", "name": "Products13_1/Product6"}, {"id": "IVs_1_13", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[62]"}, {"id": "IVs_1_14", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[11]"}, {"id": "Products13_1/Product5", "type": 1, "tooltip": "Products13_1/Product5", "name": "Products13_1/Product5"}, {"id": "IVs_1_15", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[62]"}, {"id": "IVs_1_16", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[11]"}, {"id": "Products13_1/Product4", "type": 1, "tooltip": "Products13_1/Product4", "name": "Products13_1/Product4"}, {"id": "IVs_1_17", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[63]"}, {"id": "IVs_1_18", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[10]"}, {"id": "Products13_1/Product3", "type": 1, "tooltip": "Products13_1/Product3", "name": "Products13_1/Product3"}, {"id": "IVs_1_19", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[63]"}, {"id": "IVs_1_20", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[10]"}, {"id": "Products13_1/Product2", "type": 1, "tooltip": "Products13_1/Product2", "name": "Products13_1/Product2"}, {"id": "IVs_1_21", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[62]"}, {"id": "IVs_1_22", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[10]"}, {"id": "Products13_1/Product1", "type": 1, "tooltip": "Products13_1/Product1", "name": "Products13_1/Product1"}, {"id": "IVs_1_23", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[62]"}, {"id": "IVs_1_24", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[10]"}, {"id": "Sums4.3/Sum3", "type": 2, "tooltip": "Sums4.3/Sum3", "name": "Sums4.3/Sum3"}, {"id": "Products20_1/Product4", "type": 1, "tooltip": "Products20_1/Product4", "name": "Products20_1/Product4"}, {"id": "IVs_1_25", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[51]"}, {"id": "IVs_1_26", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[23]"}, {"id": "Products20_1/Product3", "type": 1, "tooltip": "Products20_1/Product3", "name": "Products20_1/Product3"}, {"id": "IVs_1_27", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[50]"}, {"id": "IVs_1_28", "type": 0, "tooltip": "IVs_1", "name": "IVs_1[23]"}, {"id": "Products20_1/Product2", "type": 1, "tooltip": "Products20_1/Product2", "name": "Products20_1/Product2 ...

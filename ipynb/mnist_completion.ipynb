# %%
import libspn as spn
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import scipy as scp

# %% [markdown]
# # Params

# %% [markdown]
# ### Structure

# %%
# Type of input distributions for dense generator
input_dist = spn.DenseSPNGenerator.InputDist.RAW

num_decomps=1
num_subsets=5
num_mixtures=3

# Number of input mixtures for dense generator
num_input_mixtures = 2

# %% [markdown]
# ### Learning

# %%
# Additive smoothing during learning
additive_smoothing=100
min_additive_smoothing=1
smoothing_decay=0.2

# Weight initialization
# weight_init_value = 1
weight_init_value = spn.ValueType.RANDOM_UNIFORM(10, 11)

# Type of inference during upward pass of learning
value_inference_type = spn.InferenceType.MARGINAL

# %% [markdown]
# # Training Set

# %%
datasets = tf.contrib.learn.datasets.mnist.read_data_sets("/home/pronobis/Data/mnist")
# Out:
# Extracting /home/pronobis/Data/mnist/train-images-idx3-ubyte.gz
# Extracting /home/pronobis/Data/mnist/train-labels-idx1-ubyte.gz
# Extracting /home/pronobis/Data/mnist/t10k-images-idx3-ubyte.gz
# Extracting /home/pronobis/Data/mnist/t10k-labels-idx1-ubyte.gz

# %%
def show_mnist(img):
    img=np.reshape(img, (14,14))
    plt.imshow(img, interpolation='none')
    plt.show()

# %% [markdown]
# ### Process data

# %%
def process_set(data):
    threshold = 20
    images = np.reshape(data, (-1, 28,28))
    resized=[]
    for i in range(images.shape[0]):
        resized.append((scp.misc.imresize(images[i, :, :], 0.5, interp='nearest').ravel() > threshold).astype(dtype=int))
    images=np.vstack(resized)
    return images

# %%
train_images = process_set(datasets.train.images)
train_labels = datasets.train.labels
test_labels = datasets.test.labels
validation_labels = datasets.validation.labels

# %%
show_mnist(train_images[19])

# %%
train_images_0 = train_images[train_labels==0]
train_images_1 = train_images[train_labels==1]

# %%
print(train_images_0.shape)
show_mnist(train_images_0[334])
print(train_images_1.shape)
show_mnist(train_images_1[22])
# Out:
# (5444, 196)
# (6179, 196)

# %% [markdown]
# # Generate SPN structure

# %%
ivs = spn.IVs(num_vars=196, num_vals=2)
dense_gen = spn.DenseSPNGenerator(num_decomps=num_decomps, num_subsets=num_subsets, num_mixtures=num_mixtures, 
                                  input_dist=input_dist, 
                                  num_input_mixtures=num_input_mixtures)
root = dense_gen.generate(ivs)
spn.generate_weights(root, init_value=weight_init_value)
print(root.get_num_nodes())
# Out:
# 4365

# %% [markdown]
# # Add Learning Ops

# %%
additive_smoothing_var = tf.Variable(additive_smoothing, dtype=spn.conf.dtype)
learning = spn.EMLearning(root, log=True, value_inference_type = value_inference_type,
                          additive_smoothing=additive_smoothing_var)
init_weights = spn.initialize_weights(root)
reset_accumulators = learning.reset_accumulators()
accumulate_updates = learning.accumulate_updates()
update_spn = learning.update_spn()
train_likelihood=learning.value.values[root]
avg_train_likelihood = tf.reduce_mean(train_likelihood)

# %% [markdown]
# # Run Training

# %%
sess=None

# %%
train_set = np.concatenate([train_images_0, train_images_1], 0)

if sess is not None:
    sess.close()
sess = tf.Session()

sess.run(init_weights)
sess.run(reset_accumulators)

num_batches=1
batch_size = train_set.shape[0] // num_batches
prev_likelihood = 100
likelihood = 0
epoch = 0
while abs(prev_likelihood - likelihood)>0.1:
    prev_likelihood=likelihood
    likelihoods = []
    for batch in range(num_batches):
        start = (batch)*batch_size
        stop = (batch+1)*batch_size
        print("EPOCH", epoch, "BATCH", batch, "SAMPLES", start, stop)
        # Adjust smoothing
        ads=max(np.exp(-epoch*smoothing_decay)*additive_smoothing, min_additive_smoothing)
        sess.run(additive_smoothing_var.assign(ads))
        print("Smoothing: ", sess.run(additive_smoothing_var)) 
        # Run accumulate_updates
        train_likelihoods_arr, avg_train_likelihood_val, _, = \
                sess.run([train_likelihood, avg_train_likelihood, accumulate_updates],
                        feed_dict={ivs: train_set[start:stop]})
        # Print avg likelihood of this batch data on previous batch weights
        print("Avg likelihood (this batch data on previous weights): %s" % (avg_train_likelihood_val))
        likelihoods.append(avg_train_likelihood_val)
        # Update weights
        sess.run(update_spn)
    likelihood = sum(likelihoods) / len(likelihoods)
    print("Avg likelihood: %s" % (likelihood))
    epoch+=1
    sess.run(reset_accumulators)
# Out:
# EPOCH 0 BATCH 0 SAMPLES 0 11623
# Smoothing:  100.0
# Avg likelihood (this batch data on previous weights): -135.701
# Avg likelihood: -135.701416016
# EPOCH 1 BATCH 0 SAMPLES 0 11623
# Smoothing:  81.8731
# Avg likelihood (this batch data on previous weights): -67.6618
# Avg likelihood: -67.6617584229
# EPOCH 2 BATCH 0 SAMPLES 0 11623
# Smoothing:  67.032
# Avg likelihood (this batch data on previous weights): -64.7269
# Avg likelihood: -64.7268981934
# EPOCH 3 BATCH 0 SAMPLES 0 11623
# Smoothing:  54.8812
# Avg likelihood (this batch data on previous weights): -62.3097
# Avg likelihood: -62.3096733093
# EPOCH 4 BATCH 0 SAMPLES 0 11623
# Smoothing:  44.9329
# Avg likelihood (this batch data on previous weights): -60.1486
# Avg likelihood: -60.1486320496
# EPOCH 5 BATCH 0 SAMPLES 0 11623
# Smoothing:  36.7879
# Avg likelihood (this batch data on previous weights): -58.2006
# Avg likelihood: -58.2005653381
# EPOCH 6 BATCH 0 SAMPLES 0 11623
# Smoothing:  30.1194
# Avg likelihood (this batch data on previous weights): -56.4661
# Avg likelihood: -56.4661407471
# EPOCH 7 BATCH 0 SAMPLES 0 11623
# Smoothing:  24.6597
# Avg likelihood (this batch data on previous weights): -54.9268
# Avg likelihood: -54.9268188477
# EPOCH 8 BATCH 0 SAMPLES 0 11623
# Smoothing:  20.1897
# Avg likelihood (this batch data on previous weights): -53.5735
# Avg likelihood: -53.5735015869
# EPOCH 9 BATCH 0 SAMPLES 0 11623
# Smoothing:  16.5299
# Avg likelihood (this batch data on previous weights): -52.3932
# Avg likelihood: -52.3931808472
# EPOCH 10 BATCH 0 SAMPLES 0 11623
# Smoothing:  13.5335
# Avg likelihood (this batch data on previous weights): -51.3698
# Avg likelihood: -51.369758606
# EPOCH 11 BATCH 0 SAMPLES 0 11623
# Smoothing:  11.0803
# Avg likelihood (this batch data on previous weights): -50.4947
# Avg likelihood: -50.4946594238
# EPOCH 12 BATCH 0 SAMPLES 0 11623
# Smoothing:  9.0718
# Avg likelihood (this batch data on previous weights): -49.7439
# Avg likelihood: -49.743888855
# EPOCH 13 BATCH 0 SAMPLES 0 11623
# Smoothing:  7.42736
# Avg likelihood (this batch data on previous weights): -49.1074
# Avg likelihood: -49.1074447632
# EPOCH 14 BATCH 0 SAMPLES 0 11623
# Smoothing:  6.08101
# Avg likelihood (this batch data on previous weights): -48.5728
# Avg likelihood: -48.5727615356
# EPOCH 15 BATCH 0 SAMPLES 0 11623
# Smoothing:  4.97871
# Avg likelihood (this batch data on previous weights): -48.1276
# Avg likelihood: -48.1276245117
# EPOCH 16 BATCH 0 SAMPLES 0 11623
# Smoothing:  4.07622
# Avg likelihood (this batch data on previous weights): -47.7609
# Avg likelihood: -47.7608642578
# EPOCH 17 BATCH 0 SAMPLES 0 11623
# Smoothing:  3.33733
# Avg likelihood (this batch data on previous weights): -47.4551
# Avg likelihood: -47.4551239014
# EPOCH 18 BATCH 0 SAMPLES 0 11623
# Smoothing:  2.73237
# Avg likelihood (this batch data on previous weights): -47.2043
# Avg likelihood: -47.2043495178
# EPOCH 19 BATCH 0 SAMPLES 0 11623
# Smoothing:  2.23708
# Avg likelihood (this batch data on previous weights): -46.9948
# Avg likelihood: -46.9948272705
# EPOCH 20 BATCH 0 SAMPLES 0 11623
# Smoothing:  1.83156
# Avg likelihood (this batch data on previous weights): -46.8214
# Avg likelihood: -46.8213768005
# EPOCH 21 BATCH 0 SAMPLES 0 11623
# Smoothing:  1.49956
# Avg likelihood (this batch data on previous weights): -46.6772
# Avg likelihood: -46.6771736145
# EPOCH 22 BATCH 0 SAMPLES 0 11623
# Smoothing:  1.22773
# Avg likelihood (this batch data on previous weights): -46.5607
# Avg likelihood: -46.5606689453
# EPOCH 23 BATCH 0 SAMPLES 0 11623
# Smoothing:  1.00518
# Avg likelihood (this batch data on previous weights): -46.4667
# Avg likelihood: -46.4667434692

# %% [markdown]
# # Generate Testing Ops

# %%
mpe_state_gen = spn.MPEState(log=True, value_inference_type=spn.InferenceType.MPE)

# %%
mpe_state = mpe_state_gen.get_state(root, ivs)

# %% [markdown]
# # Run Testing

# %%
mpe_val=sess.run(mpe_state, feed_dict={ivs: np.ones((1, 14*14), dtype=int) * -1})
show_mnist(mpe_val)

# %%
zero = train_images_0[1510]
half_zero = np.concatenate([zero[:7*14], 
                           np.ones((7*14), dtype=int) * -1])
show_mnist(zero)
mpe_val=sess.run(mpe_state, 
                 feed_dict={ivs:[half_zero]})
show_mnist(mpe_val)

# %%
one = train_images_1[1510]
half_one = np.concatenate([one[:7*14], 
                           np.ones((7*14), dtype=int) * -1])
show_mnist(one)
mpe_val=sess.run(mpe_state, 
                 feed_dict={ivs:[half_one]})
show_mnist(mpe_val)
